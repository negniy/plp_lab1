# %% [markdown]
# # Степанов Дмитрий 6311
# ## Лабораторная работа №1

# %% [markdown]
# Результаты подсчета времени для перемножения квадратных матриц в файле time_result.txt, проверка результата перемножения в check_result.txt
#
# По результам работы был составлен график зависимости затраченного времени на перемножение двух матриц от размера матрицы nxn.

# %%
import matplotlib.pyplot as plt

# %%
list_of_size = [10, 20, 50, 100, 200, 500, 750, 1000]
list_of_times = [0, 1, 11, 74, 645, 9531, 32554, 77496]
plt.plot(list_of_size, list_of_times)
plt.ylabel('Время перемножения матриц, мс')
plt.xlabel('Кол-во эл-тов в матрице')
plt.show()

# %% [markdown]
# Вывод: время потраченное на перемножение матриц нелинейно зависит от кол-ва элементов матрицы. Зависимость похожа на экспоненциальную

# %% [markdown]
# ## Лабораторная работа №2

# %% [markdown]
# Характеристики компьютера:
#
# - Процессор - Intel(R) Core(TM) i5-9300H CPU @ 2.40GHz   2.40 GHz (4 ядра и 8 потоков)
# - Оперативная память - 8,0 ГБ
# - Тип системы - 64-разрядная операционная система, процессор x64
# - Видеокарта - NVIDIA GeForce GTX 1650

# %% [markdown]
# В данной л/р я модифицировал программу из л/р №1 для параллельной работы по технологии OpenMP.
# Файлы с результатами времени находятся в /plp_lab2/plp_lab2/time_resultn.txt, где n - кол-во потоков

# %%
list_of_size = [10, 20, 50, 100, 200, 500, 750, 1000]
list_of_times1 = [0.0002914, 0.0005617, 0.0068456, 0.0342058, 0.278792, 4.60778, 12.3786, 33.1925]
list_of_times2 = [0.0007823, 0.0001799, 0.0018424, 0.0164654, 0.113756, 2.02665, 6.86129, 17.7606]
list_of_times4 = [0.0018231, 0.000277, 0.0022902, 0.0127043, 0.0792748, 1.23732, 4.28736, 10.8414]
list_of_times8 = [0.0032867, 0.0002638, 0.0014022, 0.0138749, 0.0617, 1.00023, 3.45693, 8.24552]
plt.plot(list_of_size, list_of_times1, label ="1")
plt.plot(list_of_size, list_of_times2, label ="2")
plt.plot(list_of_size, list_of_times4, label ="4")
plt.plot(list_of_size, list_of_times8, label ="8")
plt.legend(loc='best')
plt.ylabel('Время перемножения матриц, с')
plt.xlabel('Кол-во эл-тов в матрице')
plt.show()

# %% [markdown]
# доверительные интервалы:![image.png](attachment:image.png)

# %% [markdown]
# ## Лабораторная работа №3

# %% [markdown]
# В данной л/р я модифицировал программу из л/р №1 для параллельной работы по технологии MPI на суперкомпьютере С.Королёв.

# %%
list_of_size = [10, 20, 50, 100, 200, 500, 750, 1000]
list_of_times1 = [0.00002105,
0.001253,
0.009244,
1.03349,
1.81933,
2.84124,
4.21792,
9.07144
]
list_of_times2 = [0.000022737886549,
0.000732593218084,
0.00567483109426,
0.5566325382,
0.922791363546,
1.421483002,
2.2533681698,
4.49441769528
]
list_of_times4 = [0.000016811629431,
0.000370925641189,
0.0030002196993,
0.282282572803,
0.47683199125,
0.81861656976,
1.1400989282,
2.28763214868
]
list_of_times8 = [0.0000162143901843,
0.000175370716092,
0.00134094734172,
0.150754819808,
0.247445030888,
0.357835928247,
0.620372937072,
1.34680199064
]
plt.plot(list_of_size, list_of_times1, label ="1")
plt.plot(list_of_size, list_of_times2, label ="2")
plt.plot(list_of_size, list_of_times4, label ="4")
plt.plot(list_of_size, list_of_times8, label ="8")
plt.legend(loc='best')
plt.ylabel('Время перемножения матриц, с')
plt.xlabel('Кол-во эл-тов в матрице')
plt.show()

# %% [markdown]
# доверительные интервалы:
# ![image.png](attachment:image.png)
